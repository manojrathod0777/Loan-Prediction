# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/LoanData (5).csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["Loan_ID"].unique()
# Out:
# array(['LP001002', 'LP001003', 'LP001005', 'LP001006', 'LP001008',
#        'LP001011', 'LP001013', 'LP001014', 'LP001018', 'LP001020',
#        'LP001024', 'LP001027', 'LP001028', 'LP001029', 'LP001030',
#        'LP001032', 'LP001034', 'LP001036', 'LP001038', 'LP001041',
#        'LP001043', 'LP001046', 'LP001047', 'LP001050', 'LP001052',
#        'LP001066', 'LP001068', 'LP001073', 'LP001086', 'LP001087',
#        'LP001091', 'LP001095', 'LP001097', 'LP001098', 'LP001100',
#        'LP001106', 'LP001109', 'LP001112', 'LP001114', 'LP001116',
#        'LP001119', 'LP001120', 'LP001123', 'LP001131', 'LP001136',
#        'LP001137', 'LP001138', 'LP001144', 'LP001146', 'LP001151',
#        'LP001155', 'LP001157', 'LP001164', 'LP001179', 'LP001186',
#        'LP001194', 'LP001195', 'LP001197', 'LP001198', 'LP001199',
#        'LP001205', 'LP001206', 'LP001207', 'LP001213', 'LP001222',
#        'LP001225', 'LP001228', 'LP001233', 'LP001238', 'LP001241',
# ...

# %%
df.drop(columns=["Loan_ID"],inplace=True)

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
df["Married"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["Married"].value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
df["Dependents"].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df["Dependents"].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df["Education"].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df["Education"].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df["Self_Employed"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["Self_Employed"].value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
df["ApplicantIncome"].unique()
# Out:
# array([ 5849,  4583,  3000,  2583,  6000,  5417,  2333,  3036,  4006,
#        12841,  3200,  2500,  3073,  1853,  1299,  4950,  3596,  3510,
#         4887,  2600,  7660,  5955,  3365,  3717,  9560,  2799,  4226,
#         1442,  3750,  4166,  3167,  4692,  3500, 12500,  2275,  1828,
#         3667,  3748,  3600,  1800,  2400,  3941,  4695,  3410,  5649,
#         5821,  2645,  4000,  1928,  3086,  4230,  4616, 11500,  2708,
#         2132,  3366,  8080,  3357,  3029,  2609,  4945,  5726, 10750,
#         7100,  4300,  3208,  1875,  4755,  5266,  1000,  3333,  3846,
#         2395,  1378,  3988,  2366,  8566,  5695,  2958,  6250,  3273,
#         4133,  3620,  6782,  2484,  1977,  4188,  1759,  4288,  4843,
#        13650,  4652,  3816,  3052, 11417,  7333,  3800,  2071,  5316,
#         2929,  3572,  7451,  5050, 14583,  2214,  5568, 10408,  5667,
#         2137,  2957,  3692, 23803,  3865, 10513,  6080, 20166,  2014,
# ...

# %%
df["ApplicantIncome"].value_counts()
# Out:
# ApplicantIncome
# 2500    9
# 4583    6
# 6000    6
# 2600    6
# 3333    5
#        ..
# 3244    1
# 4408    1
# 3917    1
# 3992    1
# 7583    1
# Name: count, Length: 505, dtype: int64

# %%
df["CoapplicantIncome"].unique()
# Out:
# array([0.00000000e+00, 1.50800000e+03, 2.35800000e+03, 4.19600000e+03,
#        1.51600000e+03, 2.50400000e+03, 1.52600000e+03, 1.09680000e+04,
#        7.00000000e+02, 1.84000000e+03, 8.10600000e+03, 2.84000000e+03,
#        1.08600000e+03, 3.50000000e+03, 5.62500000e+03, 1.91100000e+03,
#        1.91700000e+03, 2.92500000e+03, 2.25300000e+03, 1.04000000e+03,
#        2.08300000e+03, 3.36900000e+03, 1.66700000e+03, 3.00000000e+03,
#        2.06700000e+03, 1.33000000e+03, 1.45900000e+03, 7.21000000e+03,
#        1.66800000e+03, 1.21300000e+03, 2.33600000e+03, 3.44000000e+03,
#        2.27500000e+03, 1.64400000e+03, 1.16700000e+03, 1.59100000e+03,
#        2.20000000e+03, 2.25000000e+03, 2.85900000e+03, 3.79600000e+03,
#        3.44900000e+03, 4.59500000e+03, 2.25400000e+03, 3.06600000e+03,
#        1.87500000e+03, 1.77400000e+03, 4.75000000e+03, 3.02200000e+03,
#        4.00000000e+03, 2.16600000e+03, 1.88100000e+03, 2.53100000e+03,
# ...

# %%
df["CoapplicantIncome"].value_counts()
# Out:
# CoapplicantIncome
# 0.0       273
# 2500.0      5
# 2083.0      5
# 1666.0      5
# 2250.0      3
#          ...
# 2791.0      1
# 1010.0      1
# 1695.0      1
# 2598.0      1
# 240.0       1
# Name: count, Length: 287, dtype: int64

# %%
df["LoanAmount"].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
df["LoanAmount"].value_counts()
# Out:
# LoanAmount
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: count, Length: 203, dtype: int64

# %%
df["Loan_Amount_Term"].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df["Loan_Amount_Term"].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
df["Credit_History"].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df["Credit_History"].value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
df["Credit_History"]=df["Credit_History"].replace({1:"good",0:"bad"})
df["Credit_History"].unique()
# Out:
# array(['good', 'bad', nan], dtype=object)

# %%
df["Credit_History"].value_counts()
# Out:
# Credit_History
# good    475
# bad      89
# Name: count, dtype: int64

# %%
df["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df["Property_Area"].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
df["Loan_Status"].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df["Loan_Status"].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
continous=["ApplicantIncome","CoapplicantIncome","LoanAmount"]

describe_categorical=["Gender","Married","Education","Self_Employed",
                      "Credit_History","Property_Area","Loan_Status"]
describe_count=["Dependents","Loan_Amount_Term"]

# %%
# apply EDA

df[continous].describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  592.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   85.587325
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.000000
# 50%        3812.500000        1188.500000  128.000000
# 75%        5795.000000        2297.250000  168.000000
# max       81000.000000       41667.000000  700.000000

# %%
plt.rcParams["figure.figsize"]=(18,8) # This line of code sets the default size of the figures created by matplotlib to a width of 18 inches and a height of 8 inches. Let's break it down:
# first argument indicates number of rows of subplots
# second argument indicates number of columns of subplot
# third argument indicates index of subplot
plt.subplot(1,3,1)
sns.histplot(df["ApplicantIncome"],kde=True)

plt.subplot(1,3,2)
sns.histplot(df["CoapplicantIncome"],kde=True)

plt.subplot(1,3,3)
sns.histplot(df["LoanAmount"],kde=True)

plt.suptitle("univariate analysis on numerical columns")
plt.show()

# %%
df[continous].skew()
# Out:
# ApplicantIncome      6.539513
# CoapplicantIncome    7.491531
# LoanAmount           2.677552
# dtype: float64

# %%
sns.pairplot(df[continous])

# %%
sns.heatmap(df[continous].corr(),annot=True)
plt.show()

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
plt.subplot(1,3,1)
sns.boxplot(df["ApplicantIncome"])

plt.subplot(1,3,2)
sns.boxplot(df["CoapplicantIncome"])

plt.subplot(1,3,3)
sns.boxplot(df["LoanAmount"])

plt.suptitle("Outliers in the Data")
plt.show()

# %%
# for descrete variable

df[describe_categorical].describe()
# Out:
#        Gender Married Education Self_Employed Credit_History Property_Area  \
# count     601     611       614           582            564           614
# unique      2       2         2             2              2             3
# top      Male     Yes  Graduate            No           good     Semiurban
# freq      489     398       480           500            475           233
#
#        Loan_Status
# count          614
# unique           2
# top              Y
# freq           422

# %%
plt.rcParams["figure.figsize"]=(18,8)

plt.subplot(2,3,1)
sns.countplot(df["Gender"])

plt.subplot(2,3,2)
sns.countplot(df["Married"])

plt.subplot(2,3,3)
sns.countplot(df["Self_Employed"])

plt.subplot(2,3,4)
sns.countplot(df["Property_Area"])

plt.subplot(2,3,5)
sns.countplot(df["Education"])

plt.subplot(2,3,6)
sns.countplot(df["Loan_Status"])

plt.suptitle("univariate analysis of categorical data/ columns")
plt.show()

# %%
 # data preparation
df["Income"]=df["ApplicantIncome"]+df["CoapplicantIncome"]
df.drop(columns=["ApplicantIncome","CoapplicantIncome"],inplace=True)

# %%
# modifying the wrong data

df["Dependents"]=df["Dependents"].replace({"3+":3})

# %%
# checking no of missing values

df.isnull().sum()
# Out:
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# Income               0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# Gender              2.117264
# Married             0.488599
# Dependents          2.442997
# Education           0.000000
# Self_Employed       5.211726
# LoanAmount          3.583062
# Loan_Amount_Term    2.280130
# Credit_History      8.143322
# Property_Area       0.000000
# Loan_Status         0.000000
# Income              0.000000
# dtype: float64

# %%
#df[df.dropna(subset=["Income","LoanAmount","Loan_Amount_Term","Credit_History"])]

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 0      Male      No          0      Graduate            No         NaN
# 1      Male     Yes          1      Graduate            No       128.0
# 2      Male     Yes          0      Graduate           Yes        66.0
# 3      Male     Yes          0  Not Graduate            No       120.0
# 4      Male      No          0      Graduate            No       141.0
# ..      ...     ...        ...           ...           ...         ...
# 609  Female      No          0      Graduate            No        71.0
# 610    Male     Yes          3      Graduate            No        40.0
# 611    Male     Yes          1      Graduate            No       253.0
# 612    Male     Yes          2      Graduate            No       187.0
# 613  Female      No          0      Graduate           Yes       133.0
#
#      Loan_Amount_Term Credit_History Property_Area Loan_Status  Income
# ...

# %%
df.dropna(subset=['Income', 'LoanAmount', 'Loan_Amount_Term',"Credit_History"],how="all")
# Out:
#      Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 0      Male      No          0      Graduate            No         NaN
# 1      Male     Yes          1      Graduate            No       128.0
# 2      Male     Yes          0      Graduate           Yes        66.0
# 3      Male     Yes          0  Not Graduate            No       120.0
# 4      Male      No          0      Graduate            No       141.0
# ..      ...     ...        ...           ...           ...         ...
# 609  Female      No          0      Graduate            No        71.0
# 610    Male     Yes          3      Graduate            No        40.0
# 611    Male     Yes          1      Graduate            No       253.0
# 612    Male     Yes          2      Graduate            No       187.0
# 613  Female      No          0      Graduate           Yes       133.0
#
#      Loan_Amount_Term Credit_History Property_Area Loan_Status  Income
# ...

# %%
# count variable replace with zero
df["Dependents"]=df["Dependents"].fillna(0)

# %%
# categorical variablle replace with mode
df["Gender"]=df["Gender"].fillna(df["Gender"].mode()[0])
df["Married"]=df["Married"].fillna(df["Married"].mode()[0])
df["Self_Employed"]=df["Self_Employed"].fillna(df["Self_Employed"].mode()[0])
df["Credit_History"] = df["Credit_History"].fillna(df['Credit_History'].mode()[0])

# %%
df['LoanAmount'] = df["LoanAmount"].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())

# %%
df.isnull().sum()
# Out:
# Gender              0
# Married             0
# Dependents          0
# Education           0
# Self_Employed       0
# LoanAmount          0
# Loan_Amount_Term    0
# Credit_History      0
# Property_Area       0
# Loan_Status         0
# Income              0
# dtype: int64

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 0      Male      No          0      Graduate            No  146.412162
# 1      Male     Yes          1      Graduate            No  128.000000
# 2      Male     Yes          0      Graduate           Yes   66.000000
# 3      Male     Yes          0  Not Graduate            No  120.000000
# 4      Male      No          0      Graduate            No  141.000000
# ..      ...     ...        ...           ...           ...         ...
# 609  Female      No          0      Graduate            No   71.000000
# 610    Male     Yes          3      Graduate            No   40.000000
# 611    Male     Yes          1      Graduate            No  253.000000
# 612    Male     Yes          2      Graduate            No  187.000000
# 613  Female      No          0      Graduate           Yes  133.000000
#
#      Loan_Amount_Term Credit_History Property_Area Loan_Status  Income
# ...

# %%
# outliers treatment

# encoding
df["Gender"]=df["Gender"].map({"Male":1,"Female":0}).astype("int")
df["Married"]=df["Married"].map({"Yes":1,"No":0}).astype("int")
df["Education"]=df["Education"].map({"Graduate":1,"Not Graduate":0}).astype("int")
df["Self_Employed"]=df["Self_Employed"].map({"Yes":1,"No":0}).astype("int")
df["Property_Area"]=df["Property_Area"].map({"Rural":1,"Semiurban":0,"Urban":2}).astype("int")
df["Credit_History"].map({"good":1,"bad":0}).astype("int")
df["Loan_Status"]=df["Loan_Status"].map({"Y":1,"N":0}).astype("int")

# %%
df["Gender"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 609    0
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Gender, Length: 614, dtype: int64

# %%
df["Married"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 609    0
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Married, Length: 614, dtype: int64

# %%
df["Education"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    1
# Name: Education, Length: 614, dtype: int64

# %%
df["Married"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 609    0
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Married, Length: 614, dtype: int64

# %%
df["Self_Employed"]
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 609    0
# 610    0
# 611    0
# 612    0
# 613    1
# Name: Self_Employed, Length: 614, dtype: int64

# %%
df["Loan_Status"]
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
df["Credit_History"]
# Out:
# 0      good
# 1      good
# 2      good
# 3      good
# 4      good
#        ...
# 609    good
# 610    good
# 611    good
# 612    good
# 613     bad
# Name: Credit_History, Length: 614, dtype: object

# %%
df["Property_Area"]
# Out:
# 0      2
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 609    1
# 610    1
# 611    2
# 612    2
# 613    0
# Name: Property_Area, Length: 614, dtype: int64

# %%
# datatype conversion
df["Dependents"] = df["Dependents"].astype("int")
df["Loan_Amount_Term"] = df["Loan_Amount_Term"].astype("int")

# %%
df[["Income","LoanAmount"]].skew()
# Out:
# Income        5.633449
# LoanAmount    2.726601
# dtype: float64

# %%
# aaply the boxcox function and remove skewnwss

from scipy.stats import boxcox
df["Income"],a=boxcox(df["Income"])
df["LoanAmount"],c=boxcox(df["LoanAmount"])

# %%
df[["Income","LoanAmount"]].skew()
# Out:
# Income       -0.034662
# LoanAmount    0.030458
# dtype: float64

# %%
df["Loan_Amount_Term"]=df["Loan_Amount_Term"]/12

# %%
df["Loan_Status"]
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        0           0          1              0    6.034999
# 1         1        1           1          1              0    5.841340
# 2         1        1           0          1              1    4.914615
# 3         1        1           0          0              0    5.749027
# 4         1        0           0          1              0    5.980529
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          1              0    5.014562
# 610       1        1           3          1              0    4.243627
# 611       1        1           1          1              0    6.843401
# 612       1        1           2          1              0    6.392580
# 613       0        0           0          1              1    5.896360
#
#      Loan_Amount_Term Credit_History  Property_Area  Loan_Status    Income
# ...

# %%
df["Credit_History"]=df["Credit_History"].map({"good":1,"bad":0}).astype("int")

# %%
df["Credit_History"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Credit_History, Length: 614, dtype: int64

# %%
# X&y

X=df.drop("Loan_Status",axis=1)
y=df["Loan_Status"]

# %%
# identify the best random state number
Train=[]
Test=[]
CV=[]

for i in range(0,101):
  from sklearn.model_selection import train_test_split
  X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)

  from sklearn.linear_model import LogisticRegression
  log_default=LogisticRegression()
  log_default.fit(X_train,y_train)

  ypred_train=log_default.predict(X_train)
  ypred_test=log_default.predict(X_test)

  from sklearn.metrics import accuracy_score
  Train.append(accuracy_score(y_train,ypred_train))
  Test.append(accuracy_score(y_test,ypred_test))

  from sklearn.model_selection import cross_val_score
  CV.append(cross_val_score(log_default,X_train,y_train,cv=5,scoring="accuracy").mean())

em=pd.DataFrame(({"Train":Train,"Test":Test,"CV":CV}))
gm=em[(abs(em["Train"]-em["Test"])<=0.05) & (abs(em["Test"]-em["CV"])<=0.05)]
rs=gm[gm["CV"]==gm["CV"].max()].index.to_list()[0]
print("best random_state numbers:",rs)
# Out:
# best random_state numbers: 2

# %%
# train-test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
# 4. Decission Tree Model

# HyperParameter tuning
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# model
estimator = DecisionTreeClassifier(random_state=0)
# parameters
param_grid = {"criterion":["gini","entropy"],"max_depth":[1,2,3,4,5]}
grid = GridSearchCV(estimator,param_grid, scoring="accuracy", cv=5)

grid.fit(X_train,y_train)

grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3}

# %%
# Final Decission Tree Model

# model with best hyper parameter
final_dt_model = DecisionTreeClassifier(criterion="gini",max_depth=1,random_state=0)
final_dt_model.fit(X_train,y_train)

ypred_train = final_dt_model.predict(X_train)
ypred_test = final_dt_model.predict(X_test)

# evaluation

print("Train_accuracy",accuracy_score(ypred_train,y_train))
print("Test_accuracy",accuracy_score(ypred_test,y_test))
print("Cross_Val_Score",cross_val_score(final_dt_model,X,y,cv=5).mean())

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,ypred_test)
# Out:
# Train_accuracy 0.8187372708757638
# Test_accuracy 0.7723577235772358
# Cross_Val_Score 0.809462881514061
# array([[13, 26],
#        [ 2, 82]])
